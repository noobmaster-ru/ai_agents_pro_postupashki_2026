# %% [markdown]
# # Диагностика Python · День −2
#
# Десять микрозадач на то, что понадобится с первого дня курса. Впишите код вместо `# ваш код` и запустите ячейку: если `assert` не ругается и печатается «OK», задача решена.
#
# **Это самопроверка, а не экзамен.** Если больше двух-трёх задач не даются — не страшно, но стоит вечер потратить на добор (ссылки внизу), иначе на первой неделе будет тяжело.

# %% [markdown]
# ### Задача 1. Форматирование строк
# Соберите строку `Цена: 149₽` из переменной `price = 149` через f-строку.

# %%
price = 149
result = f'Цена: {price}₽'  # ваш код: используйте f'...'

assert result == 'Цена: 149₽', result
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 2. Индексация словаря
# Достаньте из `data` текст ответа. Путь: `choices` → первый элемент → `message` → `content`.

# %%
data = {'choices': [{'message': {'content': 'привет'}}]}
content = data['choices'][0]['message']['content']  # ваш код

assert content == 'привет', content
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 3. Списки и срезы
# Верните последние два элемента списка `xs`.

# %%
xs = [10, 20, 30, 40, 50]
last_two = xs[-2:]  # ваш код (срез)

assert last_two == [40, 50], last_two
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 4. Функция с аргументом по умолчанию
# Напишите функцию `greet(name, greeting='Привет')`, возвращающую `'Привет, Аня!'`.

# %%
def greet(name, greeting='Привет'):
    return f'{greeting}, {name}!'  # ваш код

assert greet('Аня') == 'Привет, Аня!'
assert greet('Ян', 'Здравствуй') == 'Здравствуй, Ян!'
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 5. List comprehension
# Из `nums` соберите список квадратов только чётных чисел.

# %%
nums = [1, 2, 3, 4, 5, 6]
squares = [x**2 for x in nums if x % 2 == 0]  # ваш код одной строкой

assert squares == [4, 16, 36], squares
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 6. Обработка ошибок
# Верните `int` из строки, а если не число — верните `0`. Заполните тело.

# %%
def to_int(s):
    try:
        return int(s)
    except ValueError:
        return 0

assert to_int('42') == 42
assert to_int('abc') == 0
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 7. Словарь: перебор
# Посчитайте сумму значений словаря `prices`.

# %%
prices = {'a': 100, 'b': 250, 'c': 50}
total = sum(prices.values())  # ваш код

assert total == 400, total
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 8. JSON: разбор строки
# Распарсите JSON-строку и достаньте значение поля `city`.

# %%
import json
raw = '{"user": "Ян", "city": "Казань"}'
city = json.loads(raw)['city']  # ваш код

assert city == 'Казань', city
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 9. Условие и возврат
# Функция `sign(x)` возвращает 'плюс', 'минус' или 'ноль'.

# %%
def sign(x):
    if x > 0:
        return 'плюс'
    elif x < 0:
        return 'минус'
    else:
        return 'ноль'

assert sign(5) == 'плюс' and sign(-3) == 'минус' and sign(0) == 'ноль'
print('OK')
# Out:
# OK

# %% [markdown]
# ### Задача 10. Соберём вместе: мини-разбор ответа
# Дан список сообщений. Верните `content` последнего сообщения с ролью `assistant`.

# %%
msgs = [
    {'role': 'user', 'content': 'вопрос'},
    {'role': 'assistant', 'content': 'первый ответ'},
    {'role': 'user', 'content': 'ещё вопрос'},
    {'role': 'assistant', 'content': 'второй ответ'},
]
last_answer = msgs[-1]['content']  # ваш код

assert last_answer == 'второй ответ', last_answer
print('OK')
# Out:
# OK

# %% [markdown]
# ---
# ### Если задачи даются тяжело
#
# Это не повод бросать курс, но повод подтянуть основы за вечер:
#
# - Официальный туториал Python (разделы про списки, словари, функции): [docs.python.org/3/tutorial](https://docs.python.org/3/tutorial/)
# - Короткий курс по Python на Stepik или «Поехали!» — любой, где есть практика руками
# - Задачи 2, 8, 10 — про разбор JSON и словарей. Это ровно то, чем вы будете заниматься каждый день на курсе, поэтому на них стоит потратить время в первую очередь.
